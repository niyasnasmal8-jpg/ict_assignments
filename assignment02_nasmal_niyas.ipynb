# %% [markdown]
# <a href="https://colab.research.google.com/github/niyasnasmal8-jpg/ict_assignments/blob/main/assignment02_nasmal_niyas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. fizzbuzz

# %%
num= int(input('enter a number between 1 to 100: '))
for i in range(0, 101):
  if num%3 == 0 and num % 5 == 0:
     print("FizzBuzz")
  elif num% 3 == 0:
     print("Fizz")
     break
  elif num%5 == 0:
    print("Buzz")
    break
  else:
    print('not divisible ')
# Out:
# enter a number between 1 to 100: 40
# Buzz

# %% [markdown]
# 2.Electricity Bill calculator

# %%
n=int(input("enter the number of unit consumed : "))
totalamount = 0

if n <=100:
   totalamount = n*5
elif n <= 200:
   totalamount = (100*5) + (n-100) * 7
else:
   totalamount = (100*5) + (100*7)+((n-200)*10)
print(f"Total Bill amount :{totalamount}")
# Out:
# enter the number of unit consumed : 245
# Total Bill amount :1650

# %% [markdown]
# 3. Display a pattern for a simple progress indicator

# %%
for i in range(1,6):
  print("*" * i)
# Out:
# *
# **
# ***
# ****
# *****

# %% [markdown]
# 4. Palindrome

# %%
pal = str(input("Enter a number or string:"))
rev_pal = pal[::-1]

if rev_pal == pal:
  print(pal,"is a palindrome")
else:
  print(pal,"is not a palindrome")
# Out:
# Enter a number or string:121
# 121 is a palindrome
